# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    "Name": ["Ram", "Shyam"],
    "Marks": [40,50]
})
print(df)
# Out:
#     Name  Marks
# 0    Ram     40
# 1  Shyam     50

# %%
s = pd.Series([12,13,14,15], index=["a","b","c","d"])
print(s)
# Out:
# a    12
# b    13
# c    14
# d    15
# dtype: int64

# %%
data = {
    "Name": ["Ram", "Shyam", "Hari"],
    "Marks": [23,34,54],
    "Address": ["Dhangadhi", "Aatriya", "Mahendranagar"]
    }

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Marks        Address
# 0    Ram     23      Dhangadhi
# 1  Shyam     34        Aatriya
# 2   Hari     54  Mahendranagar

# %%
print(df.head(1))
# Out:
#   Name  Marks    Address
# 0  Ram     23  Dhangadhi

# %%
print(df.tail(2))
# Out:
#     Name  Marks        Address
# 1  Shyam     34        Aatriya
# 2   Hari     54  Mahendranagar

# %%
print(df.shape)
# Out:
# (3, 3)

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      str
#  1   Marks    3 non-null      int64
#  2   Address  3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes
# None

# %%
df =  pd.read_csv("salary.csv")
print(df)
# Out:
#     Name Department   Salary   Age
# 0    Ram         IT  50000.0  25.0
# 1  Shyam         HR  40000.0  30.0
# 2   Hari         IT      NaN  28.0
# 3   Sita    Finance  60000.0   NaN
# 4   Gita         HR  45000.0  26.0

# %%
print(df[["Salary","Name"]])
# Out:
#     Salary   Name
# 0  50000.0    Ram
# 1  40000.0  Shyam
# 2      NaN   Hari
# 3  60000.0   Sita
# 4  45000.0   Gita

# %%
clean_df = df.dropna()
print(clean_df)
# Out:
#     Name Department   Salary   Age
# 0    Ram         IT  50000.0  25.0
# 1  Shyam         HR  40000.0  30.0
# 4   Gita         HR  45000.0  26.0

# %%
print(df.dropna(subset=["Salary"]))
# Out:
#     Name Department   Salary   Age
# 0    Ram         IT  50000.0  25.0
# 1  Shyam         HR  40000.0  30.0
# 3   Sita    Finance  60000.0   NaN
# 4   Gita         HR  45000.0  26.0

# %%
print(df.dropna(axis=1))   #default axis=0
# Out:
#     Name Department
# 0    Ram         IT
# 1  Shyam         HR
# 2   Hari         IT
# 3   Sita    Finance
# 4   Gita         HR

# %%
print(df.head())
# Out:
#     Name Department   Salary   Age
# 0    Ram         IT  50000.0  25.0
# 1  Shyam         HR  40000.0  30.0
# 2   Hari         IT      NaN  28.0
# 3   Sita    Finance  60000.0   NaN
# 4   Gita         HR  45000.0  26.0

# %%
print(df.tail(3))
# Out:
#    Name Department   Salary   Age
# 2  Hari         IT      NaN  28.0
# 3  Sita    Finance  60000.0   NaN
# 4  Gita         HR  45000.0  26.0

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      str
#  1   Department  5 non-null      str
#  2   Salary      4 non-null      float64
#  3   Age         4 non-null      float64
# dtypes: float64(2), str(2)
# memory usage: 292.0 bytes
# None

# %%
print(df["Salary"][0])
# Out:
# 50000.0
